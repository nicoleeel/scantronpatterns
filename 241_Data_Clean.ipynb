# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('241CleandataNOIncompletes.csv')

# %%
df.head()
# Out:
#    Group     StartDate        EndDate      Status       IPAddress  Progress  \
# 0      2  7/11/17 9:46   7/11/17 9:56  IP Address  98.232.116.238       100
# 1      3  7/11/17 9:41  7/11/17 10:03  IP Address  204.52.135.124       100
# 2      3  7/10/17 9:29   7/10/17 9:39  IP Address   73.254.83.211       100
# 3      3  7/11/17 9:35  7/11/17 10:04  IP Address  98.146.231.128       100
# 4      3  7/9/17 19:29   7/9/17 19:52  IP Address    65.183.218.6       100
#
#    Duration (in seconds) Finished   RecordedDate         ResponseId    ...     \
# 0                    601     True   7/11/17 9:56  R_2bTLUgDtdE9neLd    ...
# 1                   1332     True  7/11/17 10:03  R_12M5kh04xdIFw5e    ...
# 2                    569     True   7/10/17 9:39  R_1NU5yKb58Kn7GvL    ...
# 3                   1689     True  7/11/17 10:04  R_2Bx0cD1QFJz4D9n    ...
# 4                   1398     True   7/9/17 19:52  R_r7Sd4ykeDFOFnTH    ...
#
# ...

# %%
list(df)
df['Group'].groupby(df['Group']).count()
# Out:
# Group
# 1    54
# 2    53
# 3    51
# Name: Group, dtype: int64

# %%
df.drop(df.index[0])
# Out:
#      Group      StartDate        EndDate      Status        IPAddress  \
# 1        3   7/11/17 9:41  7/11/17 10:03  IP Address   204.52.135.124
# 2        3   7/10/17 9:29   7/10/17 9:39  IP Address    73.254.83.211
# 3        3   7/11/17 9:35  7/11/17 10:04  IP Address   98.146.231.128
# 4        3   7/9/17 19:29   7/9/17 19:52  IP Address     65.183.218.6
# 5        2   7/9/17 19:56   7/9/17 20:15  IP Address  137.118.203.216
# 6        3   7/9/17 19:54   7/9/17 20:14  IP Address      24.20.124.0
# 7        2   7/10/17 9:43   7/10/17 9:57  IP Address     67.253.96.35
# 8        3   7/9/17 19:22   7/9/17 19:47  IP Address    107.10.81.235
# 9        2   7/11/17 9:46  7/11/17 10:03  IP Address    67.158.18.207
# 10       2   7/9/17 19:38   7/9/17 19:57  IP Address    69.29.255.133
# 11       3   7/11/17 9:30   7/11/17 9:46  IP Address     66.227.142.3
# 12       1   7/10/17 9:38   7/10/17 9:52  IP Address    75.174.96.185
# ...

# %%
# Create scoring mechanisms

scores = [0]

for i in range(1,len(df)):
    score = 0
    if (str(df['Group'][i])) == '1':
        if (str(df['1a'][i][0])) == 'C':
            score += 1
        if (str(df['2a'][i][0])) == 'B':
            score += 1
        if (str(df['3a'][i][0])) == 'C':
            score += 1
        if (str(df['4a'][i][0])) == 'B':
            score += 1
        if (str(df['5a'][i][0])) == 'C':
            score += 1
        if (str(df['6a'][i][0])) == 'C':
            score += 1
        if (str(df['7a'][i][0])) == 'D':
            score += 1
        if (str(df['8a'][i][0])) == 'A':
            score += 1
        if (str(df['9a'][i][0])) == 'B':
            score += 1
        if (str(df['10a'][i][0])) == 'A':
            score += 1
        if (str(df['11a'][i][0])) == 'D':
            score += 1
        if (str(df['12a'][i][0])) == 'D':
            score += 1
        if (str(df['13a'][i][0])) == 'D':
            score += 1
        if (str(df['14a'][i][0])) == 'D':
            score += 1
        if (str(df['15a'][i][0])) == 'D':
            score += 1
        if (str(df['16a'][i][0])) == 'B':
            score += 1
        if (str(df['17a'][i][0])) == 'A':
            score += 1
        if (str(df['18a'][i][0])) == 'C':
            score += 1
        if (str(df['19a'][i][0])) == 'B':
            score += 1
        if (str(df['20a'][i][0])) == 'A':
            score += 1
        scores.append(score)
        print i, score
    elif (str(df['Group'][i])) == '2':
        if (str(df['1a'][i][0])) == 'A':
            score += 1
        if (str(df['2a'][i][0])) == 'A':
            score += 1
        if (str(df['3a'][i][0])) == 'A':
            score += 1
        if (str(df['4a'][i][0])) == 'A':
            score += 1
        if (str(df['5a'][i][0])) == 'A':
            score += 1
        if (str(df['6a'][i][0])) == 'A':
            score += 1
        if (str(df['7a'][i][0])) == 'A':
            score += 1
        if (str(df['8a'][i][0])) == 'A':
            score += 1
        if (str(df['9a'][i][0])) == 'A':
            score += 1
        if (str(df['10a'][i][0])) == 'A':
            score += 1
        if (str(df['11a'][i][0])) == 'A':
            score += 1
        if (str(df['12a'][i][0])) == 'A':
            score += 1
        if (str(df['13a'][i][0])) == 'A':
            score += 1
        if (str(df['14a'][i][0])) == 'A':
            score += 1
        if (str(df['15a'][i][0])) == 'A':
            score += 1
        if (str(df['16a'][i][0])) == 'A':
            score += 1
        if (str(df['17a'][i][0])) == 'A':
            score += 1
        if (str(df['18a'][i][0])) == 'A':
            score += 1
        if (str(df['19a'][i][0])) == 'A':
            score += 1
        if (str(df['20a'][i][0])) == 'A':
            score += 1
        scores.append(score)
        print i, score
    elif (str(df['Group'][i])) == '3':
        if (str(df['1a'][i][0])) == 'A':
            score += 1
        if (str(df['2a'][i][0])) == 'B':
            score += 1
        if (str(df['3a'][i][0])) == 'C':
            score += 1
        if (str(df['4a'][i][0])) == 'A':
            score += 1
        if (str(df['5a'][i][0])) == 'B':
            score += 1
        if (str(df['6a'][i][0])) == 'C':
            score += 1
        if (str(df['7a'][i][0])) == 'A':
            score += 1
        if (str(df['8a'][i][0])) == 'B':
            score += 1
        if (str(df['9a'][i][0])) == 'C':
            score += 1
        if (str(df['10a'][i][0])) == 'A':
            score += 1
        if (str(df['11a'][i][0])) == 'B':
            score += 1
        if (str(df['12a'][i][0])) == 'C':
            score += 1
        if (str(df['13a'][i][0])) == 'A':
            score += 1
        if (str(df['14a'][i][0])) == 'B':
            score += 1
        if (str(df['15a'][i][0])) == 'C':
            score += 1
        if (str(df['16a'][i][0])) == 'A':
            score += 1
        if (str(df['17a'][i][0])) == 'B':
            score += 1
        if (str(df['18a'][i][0])) == 'C':
            score += 1
        if (str(df['19a'][i][0])) == 'A':
            score += 1
        if (str(df['20a'][i][0])) == 'B':
            score += 1
        scores.append(score)
        print i, score
# Out:
# 1 10
# 2 9
# 3 16
# 4 10
# 5 10
# 6 11
# 7 7
# 8 10
# 9 13
# 10 14
# 11 12
# 12 16
# 13 10
# 14 7
# 15 6
# 16 9
# 17 5
# 18 11
# 19 12
# 20 10
# 21 16
# 22 11
# 23 14
# 24 8
# 25 13
# 26 15
# 27 7
# 28 13
# 29 10
# 30 10
# 31 13
# 32 16
# 33 14
# 34 13
# 35 6
# 36 13
# 37 10
# 38 7
# 39 7
# 40 4
# 41 11
# 42 10
# 43 6
# 44 10
# 45 9
# 46 4
# 47 10
# 48 6
# 49 12
# 50 8
# 51 12
# 52 8
# 53 7
# 54 13
# 55 12
# 56 10
# 57 8
# 58 12
# 59 12
# 60 10
# 61 8
# 62 4
# 63 2
# 64 15
# 65 7
# 66 14
# 67 5
# 68 6
# 69 6
# 70 6
# 71 8
# 72 7
# 73 9
# 74 12
# 75 12
# 76 12
# 77 8
# 78 8
# 79 6
# 80 11
# 81 3
# 82 4
# 83 6
# 84 12
# 85 13
# 86 7
# 87 11
# 88 15
# 89 12
# 90 9
# 91 8
# 92 19
# 93 14
# 94 11
# 95 10
# 96 11
# 97 10
# 98 8
# 99 10
# 100 9
# 101 10
# 102 14
# 103 13
# 104 7
# 105 2
# 106 10
# 107 10
# 108 9
# 109 8
# 110 13
# 111 11
# 112 7
# 113 10
# 114 8
# 115 3
# 116 10
# 117 13
# 118 9
# 119 5
# 120 6
# 121 11
# 122 7
# 123 8
# 124 7
# 125 4
# 126 5
# 127 6
# 128 14
# 129 6
# ...

# %%
#df['Unnamed: 0']
df['final_score'] = scores

# %%
df.head()
# Out:
#    Group     StartDate        EndDate      Status       IPAddress  Progress  \
# 0      2  7/11/17 9:46   7/11/17 9:56  IP Address  98.232.116.238       100
# 1      3  7/11/17 9:41  7/11/17 10:03  IP Address  204.52.135.124       100
# 2      3  7/10/17 9:29   7/10/17 9:39  IP Address   73.254.83.211       100
# 3      3  7/11/17 9:35  7/11/17 10:04  IP Address  98.146.231.128       100
# 4      3  7/9/17 19:29   7/9/17 19:52  IP Address    65.183.218.6       100
#
#    Duration (in seconds) Finished   RecordedDate         ResponseId  \
# 0                    601     True   7/11/17 9:56  R_2bTLUgDtdE9neLd
# 1                   1332     True  7/11/17 10:03  R_12M5kh04xdIFw5e
# 2                    569     True   7/10/17 9:39  R_1NU5yKb58Kn7GvL
# 3                   1689     True  7/11/17 10:04  R_2Bx0cD1QFJz4D9n
# 4                   1398     True   7/9/17 19:52  R_r7Sd4ykeDFOFnTH
#
#       ...      21a_Browser    21a_Version  21a_Operating System  \
# ...

# %%
df.to_csv('scored241.csv')

# %%
df['Group'].groupby(df['Group']).count()
# Out:
# Group
# 1    54
# 2    53
# 3    51
# Name: Group, dtype: int64

# %%
# Create scoring mechanisms

score1a = []
score1b = []
score1c = []
score2a = []
score2b = []
score2c = []
score3a = []
score3b = []
score3c = []
score4a = []
score4b = []
score4c = []
score5a = []
score5b = []
score5c = []
score6a = []
score6b = []
score6c = []
score7a = []
score7b = []
score7c = []
score8a = []
score8b = []
score8c = []
score9a = []
score9b = []
score9c = []
score10a = []
score10b = []
score10c = []
score11a = []
score11b = []
score11c = []
score12a = []
score12b = []
score12c = []
score13a = []
score13b = []
score13c = []
score14a = []
score14b = []
score14c = []
score15a = []
score15b = []
score15c = []
score16a = []
score16b = []
score16c = []
score17a = []
score17b = []
score17c = []
score18a = []
score18b = []
score18c = []
score19a = []
score19b = []
score19c = []
score20a = []
score20b = []
score20c = []

for i in range(1,len(df)):
    score = 0
    score2 = 0
    score3 = 0
    score4 = 0
    score5 = 0
    score6 = 0
    score7 = 0
    score8 = 0
    score9 = 0
    score10 = 0
    score11 = 0
    score12 = 0
    score13 = 0
    score14 = 0
    score15 = 0
    score16 = 0
    score17 = 0
    score18 = 0
    score19 = 0
    score20 = 0
    if (str(df['Group'][i])) == '1':
        if (str(df['1a'][i][0])) == 'C':
            score += 1
            score1a.append(score)
        if (str(df['2a'][i][0])) == 'B':
            score2 += 1
            score2a.append(score2)
        if (str(df['3a'][i][0])) == 'C':
            score3 += 1
            score3a.append(score3)
        if (str(df['4a'][i][0])) == 'B':
            score4 += 1
            score4a.append(score4)
        if (str(df['5a'][i][0])) == 'C':
            score5 += 1
            score5a.append(score5)
        if (str(df['6a'][i][0])) == 'C':
            score6 += 1
            score6a.append(score6)
        if (str(df['7a'][i][0])) == 'D':
            score7 += 1
            score7a.append(score7)
        if (str(df['8a'][i][0])) == 'A':
            score8 += 1
            score8a.append(score8)
        if (str(df['9a'][i][0])) == 'B':
            score9 += 1
            score9a.append(score9)
        if (str(df['10a'][i][0])) == 'A':
            score10 += 1
            score10a.append(score10)
        if (str(df['11a'][i][0])) == 'D':
            score11 += 1
            score11a.append(score11)
        if (str(df['12a'][i][0])) == 'D':
            score12 += 1
            score12a.append(score12)
        if (str(df['13a'][i][0])) == 'D':
            score13 += 1
            score13a.append(score13)
        if (str(df['14a'][i][0])) == 'D':
            score14 += 1
            score14a.append(score14)
        if (str(df['15a'][i][0])) == 'D':
            score15 += 1
            score15a.append(score15)
        if (str(df['16a'][i][0])) == 'B':
            score16 += 1
            score16a.append(score16)
        if (str(df['17a'][i][0])) == 'A':
            score17 += 1
            score17a.append(score17)
        if (str(df['18a'][i][0])) == 'C':
            score18 += 1
            score18a.append(score18)
        if (str(df['19a'][i][0])) == 'B':
            score19 += 1
            score19a.append(score19)
        if (str(df['20a'][i][0])) == 'A':
            score20 += 1
            score20a.append(score20)
    elif (str(df['Group'][i])) == '2':
        if (str(df['1a'][i][0])) == 'A':
            score += 1
            score1b.append(score)
        if (str(df['2a'][i][0])) == 'A':
            score2 += 1
            score2b.append(score2)
        if (str(df['3a'][i][0])) == 'A':
            score3 += 1
            score3b.append(score3)
        if (str(df['4a'][i][0])) == 'A':
            score4 += 1
            score4b.append(score4)
        if (str(df['5a'][i][0])) == 'A':
            score5 += 1
            score5b.append(score5)
        if (str(df['6a'][i][0])) == 'A':
            score6 += 1
            score6b.append(score6)
        if (str(df['7a'][i][0])) == 'A':
            score7 += 1
            score7b.append(score7)
        if (str(df['8a'][i][0])) == 'A':
            score8 += 1
            score8b.append(score8)
        if (str(df['9a'][i][0])) == 'A':
            score9 += 1
            score9b.append(score9)
        if (str(df['10a'][i][0])) == 'A':
            score10 += 1
            score10b.append(score10)
        if (str(df['11a'][i][0])) == 'A':
            score11 += 1
            score11b.append(score11)
        if (str(df['12a'][i][0])) == 'A':
            score12 += 1
            score12b.append(score12)
        if (str(df['13a'][i][0])) == 'A':
            score13 += 1
            score13b.append(score13)
        if (str(df['14a'][i][0])) == 'A':
            score14 += 1
            score14b.append(score14)
        if (str(df['15a'][i][0])) == 'A':
            score15 += 1
            score15b.append(score15)
        if (str(df['16a'][i][0])) == 'A':
            score16 += 1
            score16b.append(score16)
        if (str(df['17a'][i][0])) == 'A':
            score17 += 1
            score17b.append(score17)
        if (str(df['18a'][i][0])) == 'A':
            score18 += 1
            score18b.append(score18)
        if (str(df['19a'][i][0])) == 'A':
            score19 += 1
            score19b.append(score19)
        if (str(df['20a'][i][0])) == 'A':
            score20 += 1
            score20b.append(score20)
    elif (str(df['Group'][i])) == '3':
        if (str(df['1a'][i][0])) == 'A':
            score += 1
            score1c.append(score)
        if (str(df['2a'][i][0])) == 'B':
            score2 += 1
            score2c.append(score2)
        if (str(df['3a'][i][0])) == 'C':
            score3 += 1
            score3c.append(score3)
        if (str(df['4a'][i][0])) == 'A':
            score4 += 1
            score4c.append(score4)
        if (str(df['5a'][i][0])) == 'B':
            score5 += 1
            score5c.append(score5)
        if (str(df['6a'][i][0])) == 'C':
            score6 += 1
            score6c.append(score6)
        if (str(df['7a'][i][0])) == 'A':
            score7 += 1
            score7c.append(score7)
        if (str(df['8a'][i][0])) == 'B':
            score8 += 1
            score8c.append(score8)
        if (str(df['9a'][i][0])) == 'C':
            score9 += 1
            score9c.append(score9)
        if (str(df['10a'][i][0])) == 'A':
            score10 += 1
            score10c.append(score10)
        if (str(df['11a'][i][0])) == 'B':
            score11 += 1
            score11c.append(score11)
        if (str(df['12a'][i][0])) == 'C':
            score12 += 1
            score12c.append(score12)
        if (str(df['13a'][i][0])) == 'A':
            score13 += 1
            score13c.append(score13)
        if (str(df['14a'][i][0])) == 'B':
            score14 += 1
            score14c.append(score14)
        if (str(df['15a'][i][0])) == 'C':
            score15 += 1
            score15c.append(score15)
        if (str(df['16a'][i][0])) == 'A':
            score16 += 1
            score16c.append(score16)
        if (str(df['17a'][i][0])) == 'B':
            score17 += 1
            score17c.append(score17)
        if (str(df['18a'][i][0])) == 'C':
            score18 += 1
            score18c.append(score18)
        if (str(df['19a'][i][0])) == 'A':
            score19 += 1
            score19c.append(score19)
        if (str(df['20a'][i][0])) == 'B':
            score20 += 1
            score20c.append(score20)

print(sum(score19a))
print(sum(score19b))
print(sum(score19c))
# Out:
# 28
# 27
# 26

# %%
# I want to grab score by time to take test bucket within each group
# I want to grab score by time of day bucket within each group
# I want to grab the score distribution by gender within each group G1, G2, G3
# I want to grab the score distribution by technology within each group
# I want to look into click count

# Do any of the tests from 203 or earlier in the course seem relevant here (beyond regression)?

list(df)
# Out:
# ['Group',
#  'StartDate',
#  'EndDate',
#  'Status',
#  'IPAddress',
#  'Progress',
#  'Duration (in seconds)',
#  'Finished',
#  'RecordedDate',
#  'ResponseId',
#  'RecipientLastName',
#  'RecipientFirstName',
#  'RecipientEmail',
#  'ExternalReference',
#  'LocationLatitude',
#  'LocationLongitude',
#  'DistributionChannel',
#  'UserLanguage',
#  'G1',
#  'G2',
#  'G3',
#  '1a',
#  '2a',
#  '3a',
#  '4a',
#  '5a',
#  '6a',
#  '7a',
#  '8a',
#  '9a',
#  '10a',
#  '11a',
#  '12a',
#  '13a',
#  '14a',
#  '15a',
#  '16a',
#  '17a',
#  '18a',
#  '19a',
#  '20a',
#  '21a_Browser',
#  '21a_Version',
#  '21a_Operating System',
#  '21a_Resolution',
#  '22a_First Click',
#  '22a_Last Click',
#  '22a_Page Submit',
#  '22a_Click Count',
#  'mTurkCode',
#  'final_score']

# %%
df['final_score'].groupby(df['Group']).mean()
# Out:
# Group
# 1    9.611111
# 2    8.792453
# 3    9.647059
# Name: final_score, dtype: float64

# %%
df['final_score'].groupby(df['G1']).mean()
# Out:
# G1
# Female    9.404762
# Male      9.260274
# Name: final_score, dtype: float64

# %%
df['final_score'].groupby(df['G1']).count()
# Out:
# G1
# Female    84
# Male      73
# Name: final_score, dtype: int64

# %%
df['final_score'].groupby(df['G2']).mean()
# Out:
# G2
# Associate degree in college (2-year)                                       8.629630
# Bachelor's degree in college (4-year)                                      9.836066
# Doctoral degree                                                            6.000000
# High school graduate (high school diploma or equivalent including GED)     9.000000
# Master's degree                                                           11.000000
# Professional degree (JD, MD)                                              13.500000
# Some college but no degree                                                 8.777778
# Name: final_score, dtype: float64

# %%
df['final_score'].groupby(df['G2']).count()
# Out:
# G2
# Associate degree in college (2-year)                                      27
# Bachelor's degree in college (4-year)                                     61
# Doctoral degree                                                            1
# High school graduate (high school diploma or equivalent including GED)    23
# Master's degree                                                            8
# Professional degree (JD, MD)                                               2
# Some college but no degree                                                36
# Name: final_score, dtype: int64

# %%
df['final_score'].groupby(df['G3']).mean()
# Out:
# G3
# 18-27    8.875000
# 28-37    9.455882
# 38-47    9.520000
# > 47     9.640000
# Name: final_score, dtype: float64

# %%
df['final_score'].groupby(df['G3']).count()
# Out:
# G3
# 18-27    40
# 28-37    68
# 38-47    25
# > 47     25
# Name: final_score, dtype: int64

# %%
df['Duration (in seconds)'].convert_objects(convert_dates=False, convert_numeric=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# 0       601
# 1      1332
# 2       569
# 3      1689
# 4      1398
# 5      1167
# 6      1212
# 7       845
# 8      1503
# 9       998
# 10     1191
# 11      936
# 12      858
# 13      849
# 14      410
# 15      640
# 16     1453
# 17     1544
# 18      677
# 19     1760
# 20      973
# 21      746
# 22     1183
# 23     1436
# 24      625
# 25      868
# 26      823
# 27     1294
# 28      865
# 29      391
#        ...
# 128    1660
# 129     266
# 130     769
# 131     367
# 132     894
# 133     719
# 134     366
# 135    1435
# 136    1040
# 137     457
# 138    1214
# 139     829
# 140    1467
# 141     789
# 142     207
# 143     151
# 144     784
# 145     510
# 146     767
# 147     519
# 148     971
# ...

# %%
# Could create a column w/ time buckets by seconds then add here.

df.groupby(['Group', 'G1', 'G2', 'G3']).agg({'final_score': "mean",      
                                     'Group': "count", 
                                     'Duration (in seconds)': "median"})
# Out:
#                                                                        Group  \
# Group G1     G2                                                 G3
# 1     Female Associate degree in college (2-year)               18-27      1
#                                                                 28-37      1
#                                                                 38-47      1
#              Bachelor's degree in college (4-year)              18-27      1
#                                                                 28-37      1
#                                                                 38-47      1
#                                                                 > 47       3
#              High school graduate (high school diploma or eq... 28-37      3
#                                                                 38-47      4
#                                                                 > 47       2
# ...

# %%
df.groupby(['Group', 'G1']).agg({'Group': "count"})
# Out:
#               Group
# Group G1
# 1     Female     28
#       Male       26
# 2     Female     30
#       Male       23
# 3     Female     26
#       Male       24

# %%
df.groupby(['Group', 'G3']).agg({'Group': "count"})
# Out:
#              Group
# Group G3
# 1     18-27     14
#       28-37     23
#       38-47     10
#       > 47       7
# 2     18-27     13
#       28-37     20
#       38-47     11
#       > 47       9
# 3     18-27     13
#       28-37     25
#       38-47      4
#       > 47       9

# %%
df.groupby(['Group', 'G3']).agg({'final_score': "sum"})
# Out:
#              final_score
# Group G3
# 1     18-27          127
#       28-37          234
#       38-47           88
#       > 47            70
# 2     18-27          106
#       28-37          171
#       38-47          106
#       > 47            83
# 3     18-27          122
#       28-37          238
#       38-47           44
#       > 47            88

# %%
df.groupby(['Group', 'G2']).agg({'final_score': "mean"})
# Out:
#                                                           final_score
# Group G2
# 1     Associate degree in college (2-year)                   7.857143
#       Bachelor's degree in college (4-year)                 10.294118
#       Doctoral degree                                        6.000000
#       High school graduate (high school diploma or eq...     9.833333
#       Professional degree (JD, MD)                          13.500000
#       Some college but no degree                             9.200000
# 2     Associate degree in college (2-year)                   8.700000
#       Bachelor's degree in college (4-year)                  9.200000
#       High school graduate (high school diploma or eq...     7.400000
#       Master's degree                                        6.500000
#       Some college but no degree                             9.062500
# 3     Associate degree in college (2-year)                   9.100000
# ...

# %%
# df['Duration (in seconds)'].describe()

bins = [0, 661.25, 899.50, 1249.75, 48055.00]
group_names = ['Less than 10 mins', '10-15 mins', '15-20 mins', '20+ mins']
time_buckets = pd.cut(df['Duration (in seconds)'], bins, labels=group_names)
df['time_buckets'] = pd.cut(df['Duration (in seconds)'], bins, labels=group_names)
time_buckets
# Out:
# 0      Less than 10 mins
# 1               20+ mins
# 2      Less than 10 mins
# 3               20+ mins
# 4               20+ mins
# 5             15-20 mins
# 6             15-20 mins
# 7             10-15 mins
# 8               20+ mins
# 9             15-20 mins
# 10            15-20 mins
# 11            15-20 mins
# 12            10-15 mins
# 13            10-15 mins
# 14     Less than 10 mins
# 15     Less than 10 mins
# 16              20+ mins
# 17              20+ mins
# 18            10-15 mins
# 19              20+ mins
# 20            15-20 mins
# 21            10-15 mins
# 22            15-20 mins
# 23              20+ mins
# 24     Less than 10 mins
# 25            10-15 mins
# 26            10-15 mins
# 27              20+ mins
# 28            10-15 mins
# 29     Less than 10 mins
#              ...
# 128             20+ mins
# 129    Less than 10 mins
# 130           10-15 mins
# 131    Less than 10 mins
# 132           10-15 mins
# 133           10-15 mins
# ...

# %%
# df.head()
df.groupby(['Group', 'time_buckets']).agg({'Group': "count",
                                          'final_score': "mean"})
# Out:
#                          final_score  Group
# Group time_buckets
# 1     Less than 10 mins     7.750000     12
#       10-15 mins           10.500000     16
#       15-20 mins            9.818182     11
#       20+ mins             10.000000     15
# 2     Less than 10 mins     6.687500     16
#       10-15 mins            9.000000     13
#       15-20 mins           10.000000     12
#       20+ mins             10.166667     12
# 3     Less than 10 mins     6.000000     12
#       10-15 mins           10.300000     10
#       15-20 mins           10.562500     16
#       20+ mins             11.384615     13

# %%
# df.head()
df.groupby(['Group', '21a_Browser']).agg({'Group': "count", 
                                          'final_score': "mean"})
# Out:
#                      final_score  Group
# Group 21a_Browser
# 1     Chrome            9.804348     46
#       Firefox           8.500000      8
# 2     Chrome            8.906977     43
#       Firefox           8.300000     10
# 3     Chrome            9.526316     38
#       Chrome iPhone    11.000000      1
#       Firefox           9.916667     12

# %%
df.groupby(['21a_Operating System']).agg({'Group': "count", 
                                          'final_score': "mean"})
# Out:
#                        final_score  Group
# 21a_Operating System
# Android 4.4.2             9.000000      1
# CrOS x86_64 9334.72.0     7.000000      1
# CrOS x86_64 9460.67.0    10.000000      1
# Linux x86_64             14.000000      1
# Macintosh                 9.277778     18
# Windows NT 10.0           9.511364     88
# Windows NT 5.1            6.500000      2
# Windows NT 6.1            9.250000     32
# Windows NT 6.2            8.000000      1
# Windows NT 6.3            8.750000     12
# iPhone                   11.000000      1

# %%
df.groupby(['Group', '21a_Operating System']).agg({'Group': "count", 
                                          'final_score': "mean"})
# Out:
#                              final_score  Group
# Group 21a_Operating System
# 1     Android 4.4.2             9.000000      1
#       CrOS x86_64 9460.67.0    10.000000      1
#       Macintosh                 9.333333      6
#       Windows NT 10.0           9.607143     28
#       Windows NT 6.1            9.928571     14
#       Windows NT 6.3            9.000000      4
# 2     Linux x86_64             14.000000      1
#       Macintosh                 5.600000      5
#       Windows NT 10.0           9.766667     30
#       Windows NT 5.1            6.500000      2
#       Windows NT 6.1            7.700000     10
#       Windows NT 6.3            8.200000      5
# 3     CrOS x86_64 9334.72.0     7.000000      1
#       Macintosh                11.857143      7
#       Windows NT 10.0           9.166667     30
#       Windows NT 6.1           10.000000      8
#       Windows NT 6.2            8.000000      1
#       Windows NT 6.3            9.333333      3
# ...

# %%
df.groupby(['Group']).agg({'Duration (in seconds)': "median"})
# Out:
#        Duration (in seconds)
# Group
# 1                      881.5
# 2                      846.0
# 3                      983.0

# %%
df['RecordedDate'] = pd.to_datetime(df['RecordedDate'])
df['hod'] = [r.hour for r in df.RecordedDate]

# %%
df.groupby(['Group', 'hod']).agg({'Group': "count", 
                                          'final_score': "mean"})
# Out:
#            final_score  Group
# Group hod
# 1     9       9.409091     22
#       10     10.583333     12
#       15      8.000000      1
#       19      9.555556     18
#       20      5.000000      1
# 2     9       8.041667     24
#       10      8.200000     10
#       11     11.000000      1
#       15     11.000000      1
#       19      9.461538     13
#       20     10.000000      3
#       22     16.000000      1
# 3     9       9.952381     21
#       10     10.250000     12
#       15      5.000000      1
#       19      9.000000     16
#       20     11.000000      1
