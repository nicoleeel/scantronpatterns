# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('241CleandataNOIncompletes.csv')

# %%
df.head()
# Out:
#   Unnamed: 0     StartDate        EndDate         Status       IPAddress  \
# 0      Group    Start Date       End Date  Response Type      IP Address
# 1          2  7/11/17 9:46   7/11/17 9:56     IP Address  98.232.116.238
# 2          3  7/11/17 9:41  7/11/17 10:03     IP Address  204.52.135.124
# 3          3  7/10/17 9:29   7/10/17 9:39     IP Address   73.254.83.211
# 4          3  7/11/17 9:35  7/11/17 10:04     IP Address  98.146.231.128
#
#    Progress  Duration (in seconds)  Finished   RecordedDate  \
# 0  Progress  Duration (in seconds)  Finished  Recorded Date
# 1       100                    601      TRUE   7/11/17 9:56
# 2       100                   1332      TRUE  7/11/17 10:03
# 3       100                    569      TRUE   7/10/17 9:39
# 4       100                   1689      TRUE  7/11/17 10:04
#
#           ResponseId    ...      \
# 0        Response ID    ...
# 1  R_2bTLUgDtdE9neLd    ...
# 2  R_12M5kh04xdIFw5e    ...
# 3  R_1NU5yKb58Kn7GvL    ...
# 4  R_2Bx0cD1QFJz4D9n    ...
#
#                                                  20a  \
# 0  The deadline for an assignment was Sunday, Jan...
# 1                                          E) Friday
# 2                                          B) Monday
# 3                                        E) Thursday
# 4                                          B) Monday
#
#                    21a_Browser                  21a_Version  \
# 0  Browser Meta Info - Browser  Browser Meta Info - Version
# 1                       Chrome                59.0.3071.115
# 2                       Chrome                 59.0.3071.86
# 3                       Chrome                59.0.3071.115
# 4                       Chrome                59.0.3071.115
#
#                    21a_Operating System                  21a_Resolution  \
# 0  Browser Meta Info - Operating System  Browser Meta Info - Resolution
# 1                       Windows NT 10.0                        1120x700
# 2                        Windows NT 6.1                        1536x864
# 3                       Windows NT 10.0                       1920x1080
# 4                       Windows NT 10.0                       1920x1080
#
#         22a_First Click       22a_Last Click       22a_Page Submit  \
# 0  Timing - First Click  Timing - Last Click  Timing - Page Submit
# 1                16.207               93.311                93.643
# 2                10.499              120.931               121.864
# 3                60.059              209.186               209.829
# 4                 14.74              216.488               217.087
#
#         22a_Click Count  mTurkCode
# 0  Timing - Click Count  mTurkCode
# 1                     6     495836
# 2                     6     489065
# 3                     6     260422
# 4                     6      60785
#
# [5 rows x 50 columns]

# %%
list(df)
df['Unnamed: 0'].groupby(df['Unnamed: 0']).count()
# Out:
# Unnamed: 0
# 1        54
# 2        53
# 3        51
# Group     1
# Name: Unnamed: 0, dtype: int64

# %%
df.drop(df.index[0])
# Out:
#     Unnamed: 0      StartDate        EndDate      Status        IPAddress  \
# 1            2   7/11/17 9:46   7/11/17 9:56  IP Address   98.232.116.238
# 2            3   7/11/17 9:41  7/11/17 10:03  IP Address   204.52.135.124
# 3            3   7/10/17 9:29   7/10/17 9:39  IP Address    73.254.83.211
# 4            3   7/11/17 9:35  7/11/17 10:04  IP Address   98.146.231.128
# 5            3   7/9/17 19:29   7/9/17 19:52  IP Address     65.183.218.6
# 6            2   7/9/17 19:56   7/9/17 20:15  IP Address  137.118.203.216
# 7            3   7/9/17 19:54   7/9/17 20:14  IP Address      24.20.124.0
# 8            2   7/10/17 9:43   7/10/17 9:57  IP Address     67.253.96.35
# 9            3   7/9/17 19:22   7/9/17 19:47  IP Address    107.10.81.235
# 10           2   7/11/17 9:46  7/11/17 10:03  IP Address    67.158.18.207
# 11           2   7/9/17 19:38   7/9/17 19:57  IP Address    69.29.255.133
# 12           3   7/11/17 9:30   7/11/17 9:46  IP Address     66.227.142.3
# 13           1   7/10/17 9:38   7/10/17 9:52  IP Address    75.174.96.185
# 14           2   7/9/17 19:28   7/9/17 19:43  IP Address    24.211.11.124
# 15           2   7/10/17 9:37   7/10/17 9:44  IP Address     98.102.88.42
# 16           3   7/10/17 9:29   7/10/17 9:40  IP Address    72.228.42.128
# 17           1   7/9/17 19:23   7/9/17 19:47  IP Address     68.42.175.49
# 18           2   7/9/17 19:22   7/9/17 19:48  IP Address    74.74.251.201
# 19           1   7/11/17 9:44   7/11/17 9:55  IP Address   104.14.110.135
# 20           2   7/9/17 19:23   7/9/17 19:53  IP Address    66.190.21.153
# 21           1   7/9/17 19:22   7/9/17 19:39  IP Address     68.60.99.139
# 22           1   7/9/17 19:22   7/9/17 19:35  IP Address    73.126.19.239
# 23           2   7/11/17 9:39   7/11/17 9:59  IP Address     68.36.199.27
# 24           3   7/11/17 9:29   7/11/17 9:53  IP Address    72.79.238.200
# 25           3   7/11/17 9:34   7/11/17 9:45  IP Address   208.126.198.32
# 26           3   7/9/17 19:22   7/9/17 19:37  IP Address   24.128.213.218
# 27           2   7/11/17 9:30   7/11/17 9:44  IP Address   73.211.168.236
# 28           3   7/10/17 9:36   7/10/17 9:58  IP Address    24.60.176.206
# 29           3   7/10/17 9:30   7/10/17 9:44  IP Address    99.111.60.205
# 30           1   7/10/17 9:49   7/10/17 9:55  IP Address    71.227.121.46
# ..         ...            ...            ...         ...              ...
# 129          2   7/11/17 9:29   7/11/17 9:57  IP Address   174.56.160.177
# 130          3  7/11/17 10:04  7/11/17 10:09  IP Address     72.178.19.52
# 131          1   7/11/17 9:48  7/11/17 10:01  IP Address    108.129.28.29
# 132          1   7/11/17 9:29   7/11/17 9:35  IP Address     68.59.64.228
# 133          3   7/9/17 19:25   7/9/17 19:40  IP Address    172.3.120.221
# 134          2   7/11/17 9:51  7/11/17 10:03  IP Address   107.167.229.84
# 135          2  7/11/17 10:12  7/11/17 10:19  IP Address    68.114.108.36
# 136          1   7/10/17 9:40  7/10/17 10:04  IP Address   173.17.164.176
# 137          2   7/9/17 19:53   7/9/17 20:11  IP Address   68.206.234.129
# 138          2   7/9/17 19:48   7/9/17 19:56  IP Address    66.87.121.144
# 139          3   7/11/17 9:48  7/11/17 10:08  IP Address    99.46.169.184
# 140          3   7/9/17 19:22   7/9/17 19:36  IP Address     184.91.255.0
# 141          1   7/10/17 9:30   7/10/17 9:54  IP Address      97.103.1.40
# 142          2  7/11/17 15:26  7/11/17 15:39  IP Address     97.103.19.17
# 143          1  7/10/17 10:08  7/10/17 10:12  IP Address   72.189.106.155
# 144          2  7/10/17 10:02  7/10/17 10:05  IP Address   72.189.106.155
# 145          2   7/11/17 9:34   7/11/17 9:47  IP Address   68.205.250.236
# 146          3   7/10/17 9:29   7/10/17 9:38  IP Address    50.89.180.123
# 147          1   7/9/17 19:54   7/9/17 20:07  IP Address    68.200.95.124
# 148          3  7/10/17 10:14  7/10/17 10:23  IP Address   47.201.205.198
# 149          2   7/10/17 9:39   7/10/17 9:55  IP Address     65.35.90.154
# 150          1   7/9/17 19:23   7/9/17 19:40  IP Address     75.76.60.225
# 151          3   7/11/17 9:37   7/11/17 9:46  IP Address    73.23.153.157
# 152          1  7/10/17 10:09  7/10/17 10:21  IP Address     99.66.16.161
# 153          2   7/9/17 22:19   7/9/17 22:41  IP Address      99.38.225.2
# 154          3   7/10/17 9:41   7/10/17 9:44  IP Address    98.242.255.44
# 155          3   7/11/17 9:46  7/11/17 10:07  IP Address   177.228.56.238
# 156          1   7/9/17 19:24   7/9/17 19:50  IP Address    110.54.202.63
# 157          3   7/11/17 9:42  7/11/17 10:03  IP Address  177.252.251.116
# 158          1   7/10/17 9:29   7/10/17 9:45  IP Address    190.45.169.96
#
#     Progress Duration (in seconds) Finished   RecordedDate         ResponseId  \
# 1        100                   601     TRUE   7/11/17 9:56  R_2bTLUgDtdE9neLd
# 2        100                  1332     TRUE  7/11/17 10:03  R_12M5kh04xdIFw5e
# 3        100                   569     TRUE   7/10/17 9:39  R_1NU5yKb58Kn7GvL
# 4        100                  1689     TRUE  7/11/17 10:04  R_2Bx0cD1QFJz4D9n
# 5        100                  1398     TRUE   7/9/17 19:52  R_r7Sd4ykeDFOFnTH
# 6        100                  1167     TRUE   7/9/17 20:15  R_2w4tUusC6UC1JxN
# 7        100                  1212     TRUE   7/9/17 20:14  R_2ripy1WhY4Wd95F
# 8        100                   845     TRUE   7/10/17 9:57  R_3hoJk7KH5pzXqEm
# 9        100                  1503     TRUE   7/9/17 19:47  R_Y0rFrgB9PBqTvq1
# 10       100                   998     TRUE  7/11/17 10:03  R_3DpT9jGV5QuWzgE
# 11       100                  1191     TRUE   7/9/17 19:57  R_yPGEHEaYRdPxQMp
# 12       100                   936     TRUE   7/11/17 9:46  R_d6DlHP5WYxGwBKp
# 13       100                   858     TRUE   7/10/17 9:52  R_WlD9PNe4BT0QBJn
# 14       100                   849     TRUE   7/9/17 19:43  R_5oSlelAM03PPCal
# 15       100                   410     TRUE   7/10/17 9:44  R_2Wx6tfAsuC61uCw
# 16       100                   640     TRUE   7/10/17 9:40  R_ysU9xAPju4PKUOl
# 17       100                  1453     TRUE   7/9/17 19:47  R_ymUhY9l2X9ThimJ
# 18       100                  1544     TRUE   7/9/17 19:48  R_QfvNeJAdgPNX3AR
# 19       100                   677     TRUE   7/11/17 9:55  R_1GykmDiiTk4bSM2
# 20       100                  1760     TRUE   7/9/17 19:53  R_6D93jxAosbAOMGl
# 21       100                   973     TRUE   7/9/17 19:39  R_rf3pLJQs6PRx2IV
# 22       100                   746     TRUE   7/9/17 19:35  R_1hYJqMH5a7C8MFv
# 23       100                  1183     TRUE   7/11/17 9:59  R_2DV7RtByDZnllsy
# 24       100                  1436     TRUE   7/11/17 9:53  R_3pax8zqpGskK5rn
# 25       100                   625     TRUE   7/11/17 9:45  R_a4VlmXozLIFEhoJ
# 26       100                   868     TRUE   7/9/17 19:37  R_2z6F4RhM82p4Gx6
# 27       100                   823     TRUE   7/11/17 9:44  R_vDNICijq3qZZFlL
# 28       100                  1294     TRUE   7/10/17 9:58  R_3J1WrQ3ZUuUR8fm
# 29       100                   865     TRUE   7/10/17 9:44  R_3fUJ2Zfo6ounyZn
# 30       100                   391     TRUE   7/10/17 9:55  R_1FJJvunHI1GbjGL
# ..       ...                   ...      ...            ...                ...
# 129      100                  1660     TRUE   7/11/17 9:57  R_2dilxRn6CQIkSpM
# 130      100                   266     TRUE  7/11/17 10:09  R_USdxK5pi2tCFYml
# 131      100                   769     TRUE  7/11/17 10:01  R_2RQGUeimYPmh1hg
# 132      100                   367     TRUE   7/11/17 9:35  R_2wQzxx3OQOy7nTz
# 133      100                   894     TRUE   7/9/17 19:40  R_VI11N6dgsCK9Rjb
# 134      100                   719     TRUE  7/11/17 10:03  R_1C1l13zhDStI1z2
# 135      100                   366     TRUE  7/11/17 10:19  R_1dn2g9Qpk2KSPSF
# 136      100                  1435     TRUE  7/10/17 10:04  R_d6Gn0obUkO8mIBr
# 137      100                  1040     TRUE   7/9/17 20:11  R_3QE4Az90Wqgofni
# 138      100                   457     TRUE   7/9/17 19:56  R_279BMz0EQUWoiau
# 139      100                  1214     TRUE  7/11/17 10:08  R_3NLe6ovX3QwpyQT
# 140      100                   829     TRUE   7/9/17 19:36  R_3fMExJslD95Z6d5
# 141      100                  1467     TRUE   7/10/17 9:54  R_t04u0XUcFM1UJJD
# 142      100                   789     TRUE  7/11/17 15:39  R_2atoOnClYUYuTn5
# 143      100                   207     TRUE  7/10/17 10:12  R_3VQWm75MLQ9BzS9
# 144      100                   151     TRUE  7/10/17 10:05  R_1fjdjsQZaWUeulz
# 145      100                   784     TRUE   7/11/17 9:47  R_1go6b9b8R0F7Md3
# 146      100                   510     TRUE   7/10/17 9:38  R_3fVPEsVprp0mhHg
# 147      100                   767     TRUE   7/9/17 20:07  R_1pPvMiAUJELjZIA
# 148      100                   519     TRUE  7/10/17 10:23  R_bBJXvFYxjj6TDhf
# 149      100                   971     TRUE   7/10/17 9:55  R_3dM6UQgBrnICgQs
# 150      100                  1017     TRUE   7/9/17 19:40  R_ezYk6AIIy5GZSAF
# 151      100                   566     TRUE   7/11/17 9:46  R_PTKzo2jWjdPklGx
# 152      100                   737     TRUE  7/10/17 10:21  R_2VxdRWiS5AZsyFF
# 153      100                  1345     TRUE   7/9/17 22:41  R_1KdUczeeml4SIEs
# 154      100                   195     TRUE   7/10/17 9:44  R_25NJoaWRlMlGgMY
# 155      100                  1214     TRUE  7/11/17 10:07  R_1pXwXQETM7C6ERX
# 156      100                  1547     TRUE   7/9/17 19:50  R_30elnz4Fc9PlBlg
# 157      100                  1236     TRUE  7/11/17 10:03  R_22MofKfZwCeB4CU
# 158      100                   922     TRUE   7/10/17 9:45  R_XzZKs2UlLFPMCkh
#
#        ...              20a    21a_Browser    21a_Version  \
# 1      ...        E) Friday         Chrome  59.0.3071.115
# 2      ...        B) Monday         Chrome   59.0.3071.86
# 3      ...      E) Thursday         Chrome  59.0.3071.115
# 4      ...        B) Monday         Chrome  59.0.3071.115
# 5      ...        B) Monday        Firefox             54
# 6      ...        A) Monday        Firefox             54
# 7      ...        B) Monday        Firefox             54
# 8      ...        A) Monday         Chrome  59.0.3071.115
# 9      ...        B) Monday         Chrome  59.0.3071.115
# 10     ...        A) Monday        Firefox             54
# 11     ...        A) Monday         Chrome  59.0.3071.104
# 12     ...        B) Monday         Chrome  59.0.3071.115
# 13     ...        A) Monday         Chrome  59.0.3071.115
# 14     ...        A) Monday         Chrome  59.0.3071.115
# 15     ...        A) Monday        Firefox             54
# 16     ...        B) Monday         Chrome  59.0.3071.115
# 17     ...        A) Monday         Chrome  59.0.3071.115
# 18     ...      D) Thursday         Chrome  59.0.3071.115
# 19     ...        A) Monday         Chrome  59.0.3071.115
# 20     ...        A) Monday        Firefox             54
# 21     ...        A) Monday         Chrome  59.0.3071.115
# 22     ...        A) Monday         Chrome  59.0.3071.115
# 23     ...        A) Monday         Chrome  59.0.3071.115
# 24     ...        B) Monday        Firefox             54
# 25     ...        B) Monday         Chrome  59.0.3071.115
# 26     ...        B) Monday        Firefox             54
# 27     ...        A) Monday         Chrome  59.0.3071.115
# 28     ...        B) Monday         Chrome  59.0.3071.115
# 29     ...        B) Monday         Chrome   57.0.2987.98
# 30     ...       B) Tuesday         Chrome  59.0.3071.115
# ..     ...              ...            ...            ...
# 129    ...        A) Monday         Chrome  59.0.3071.115
# 130    ...        B) Monday         Chrome  59.0.3071.115
# 131    ...        A) Monday         Chrome  59.0.3071.115
# 132    ...     C) Wednesday         Chrome  59.0.3071.115
# 133    ...        D) Friday         Chrome  59.0.3071.115
# 134    ...        A) Monday         Chrome  59.0.3071.115
# 135    ...        A) Monday         Chrome  59.0.3071.115
# 136    ...        A) Monday        Firefox             54
# 137    ...        A) Monday         Chrome  59.0.3071.115
# 138    ...       B) Tuesday         Chrome  59.0.3071.115
# 139    ...        B) Monday        Firefox             54
# 140    ...        B) Monday  Chrome iPhone  59.0.3071.102
# 141    ...        A) Monday         Chrome  59.0.3071.115
# 142    ...        A) Monday        Firefox             54
# 143    ...        E) Friday         Chrome   48.0.2564.97
# 144    ...      D) Thursday         Chrome   48.0.2564.97
# 145    ...        A) Monday         Chrome  59.0.3071.115
# 146    ...        B) Monday         Chrome  58.0.3029.140
# 147    ...     C) Wednesday         Chrome  59.0.3071.115
# 148    ...        B) Monday         Chrome  59.0.3071.115
# 149    ...        A) Monday         Chrome  59.0.3071.115
# 150    ...        A) Monday         Chrome  59.0.3071.115
# 151    ...        B) Monday         Chrome  59.0.3071.115
# 152    ...        A) Monday         Chrome  58.0.3029.110
# 153    ...        A) Monday         Chrome  59.0.3071.115
# 154    ...        B) Monday        Firefox             54
# 155    ...        B) Monday         Chrome  59.0.3071.115
# 156    ...        A) Monday        Firefox             53
# 157    ...        B) Monday         Chrome  51.0.2704.106
# 158    ...       B) Tuesday         Chrome  59.0.3071.115
#
#       21a_Operating System 21a_Resolution 22a_First Click 22a_Last Click  \
# 1          Windows NT 10.0       1120x700          16.207         93.311
# 2           Windows NT 6.1       1536x864          10.499        120.931
# 3          Windows NT 10.0      1920x1080          60.059        209.186
# 4          Windows NT 10.0      1920x1080           14.74        216.488
# 5          Windows NT 10.0      1920x1080            5.47        218.036
# 6          Windows NT 10.0      1680x1050          33.275        184.295
# 7           Windows NT 6.1      1920x1080          33.581        269.522
# 8          Windows NT 10.0      1920x1080           5.983        126.224
# 9           Windows NT 6.1       1366x768          32.101        124.924
# 10          Windows NT 6.1       1366x768          18.286         97.748
# 11            Linux x86_64       1600x900          43.822        149.559
# 12         Windows NT 10.0       1366x768          15.611        121.531
# 13         Windows NT 10.0       1600x900          14.428        142.053
# 14         Windows NT 10.0      1920x1080            6.51         79.142
# 15          Windows NT 6.1      1920x1080           3.809         39.343
# 16         Windows NT 10.0       1536x864          15.244        103.367
# 17         Windows NT 10.0       1366x768          15.769        110.579
# 18         Windows NT 10.0       1366x768           2.216         13.951
# 19          Windows NT 6.1       1600x900           18.85        139.956
# 20         Windows NT 10.0       1366x768          76.044         488.02
# 21         Windows NT 10.0       1366x768           41.98        145.953
# 22          Windows NT 6.3       1600x900              25         75.572
# 23         Windows NT 10.0       1366x768          21.627         136.77
# 24               Macintosh       1152x720         137.834        297.847
# 25         Windows NT 10.0      1920x1080          23.398         94.781
# 26         Windows NT 10.0      1776x1000          19.194        182.926
# 27         Windows NT 10.0      1920x1080          14.526        165.097
# 28         Windows NT 10.0      2560x1080          39.366        227.067
# 29         Windows NT 10.0       1152x720          15.769        141.306
# 30         Windows NT 10.0      1920x1080           8.156         60.874
# ..                     ...            ...             ...            ...
# 129        Windows NT 10.0      1280x1024          15.488         206.05
# 130        Windows NT 10.0      1600x1200           3.608         38.498
# 131        Windows NT 10.0       1366x768          25.522        112.643
# 132        Windows NT 10.0      2560x1440           0.747          0.747
# 133         Windows NT 6.3       1366x768           3.438         16.102
# 134        Windows NT 10.0       1366x768           2.099         167.29
# 135        Windows NT 10.0       1360x768          14.087         57.015
# 136         Windows NT 6.1       1680x945          36.862        187.843
# 137        Windows NT 10.0       1366x768          42.439        142.036
# 138              Macintosh       1366x768           7.377        126.747
# 139        Windows NT 10.0       1600x900          24.446         84.821
# 140                 iPhone        414x736           1.452        137.015
# 141        Windows NT 10.0       1366x768          70.881        192.938
# 142        Windows NT 10.0       1366x768          15.864        103.574
# 143         Windows NT 6.1       1600x900           8.506         15.898
# 144         Windows NT 6.1       1600x900           1.009          20.79
# 145        Windows NT 10.0      1920x1080          20.733        160.306
# 146  CrOS x86_64 9334.72.0       1366x768          23.218         89.346
# 147        Windows NT 10.0       1366x768          13.484        122.867
# 148        Windows NT 10.0      2560x1080          25.815         81.129
# 149         Windows NT 6.3       1600x900          46.338         96.406
# 150        Windows NT 10.0       1366x768          33.482        136.852
# 151        Windows NT 10.0       1366x768          15.428        110.359
# 152         Windows NT 6.1       1366x768          14.495         81.661
# 153        Windows NT 10.0      1920x1080          93.216         225.69
# 154        Windows NT 10.0       1280x720           3.066         31.985
# 155        Windows NT 10.0       1366x768           4.116          78.61
# 156          Android 4.4.2        600x976          21.687        121.504
# 157              Macintosh       1440x900          25.083         98.992
# 158        Windows NT 10.0       1536x864          51.319         213.07
#
#     22a_Page Submit 22a_Click Count mTurkCode
# 1            93.643               6    495836
# 2           121.864               6    489065
# 3           209.829               6    260422
# 4           217.087               6     60785
# 5           225.177              21    888418
# 6           186.029               5    611446
# 7           286.784               8    435468
# 8           127.069              19    441705
# 9           126.147               9    956205
# 10           99.062               7    424006
# 11          153.189               5    163242
# 12          125.199               5    393344
# 13          144.099               5    593395
# 14           79.952               5    345061
# 15           40.448               6    675517
# 16          105.282               9        64
# 17          113.914               7     84919
# 18           15.361              10    378264
# 19          141.902               8    529110
# 20          489.139               5    157045
# 21          147.212               5    622667
# 22           75.754               3    626701
# 23          137.695               6    396889
# 24          299.266               6    407455
# 25           96.149               5    705392
# 26           196.13               5    900823
# 27          165.777               5    667481
# 28          229.367               7    645816
# 29          145.187              10    396819
# 30           61.922               6    784852
# ..              ...             ...       ...
# 129         207.592               5    693364
# 130          39.256               5    480287
# 131         113.863               5    366474
# 132         163.784               1    422330
# 133         184.007              10     96336
# 134         168.468              21    364688
# 135          58.201               5    436519
# 136         190.269               6    365957
# 137         145.186               6    124478
# 138         128.447               9    260362
# 139          85.613               6    719435
# 140         137.818              38    537986
# 141         194.812               5    929096
# 142         104.875               8    297238
# 143          16.471               6    979828
# 144           21.96               5    232605
# 145         161.258               5    307381
# 146          90.835               5    382232
# 147         124.554               5    677554
# 148          81.975               7    137939
# 149          96.753               5    997672
# 150         138.129               7    843214
# 151         111.826               5    354501
# 152          83.139               5    274000
# 153         227.867               5    574156
# 154          33.005               7    432550
# 155          79.564              12    569572
# 156         122.328              36    453168
# 157         101.319               5    229105
# 158          214.03               5    780981
#
# [158 rows x 50 columns]

# %%
# Create scoring mechanisms

scores = [0]

for i in range(1,len(df)):
    score = 0
    if (str(df['Unnamed: 0'][i])) == '1':
        if (str(df['1a'][i][0])) == 'C':
            score += 1
        if (str(df['2a'][i][0])) == 'B':
            score += 1
        if (str(df['3a'][i][0])) == 'C':
            score += 1
        if (str(df['4a'][i][0])) == 'B':
            score += 1
        if (str(df['5a'][i][0])) == 'C':
            score += 1
        if (str(df['6a'][i][0])) == 'C':
            score += 1
        if (str(df['7a'][i][0])) == 'D':
            score += 1
        if (str(df['8a'][i][0])) == 'A':
            score += 1
        if (str(df['9a'][i][0])) == 'B':
            score += 1
        if (str(df['10a'][i][0])) == 'A':
            score += 1
        if (str(df['11a'][i][0])) == 'D':
            score += 1
        if (str(df['12a'][i][0])) == 'D':
            score += 1
        if (str(df['13a'][i][0])) == 'D':
            score += 1
        if (str(df['14a'][i][0])) == 'D':
            score += 1
        if (str(df['15a'][i][0])) == 'D':
            score += 1
        if (str(df['16a'][i][0])) == 'B':
            score += 1
        if (str(df['17a'][i][0])) == 'A':
            score += 1
        if (str(df['18a'][i][0])) == 'C':
            score += 1
        if (str(df['19a'][i][0])) == 'B':
            score += 1
        if (str(df['20a'][i][0])) == 'A':
            score += 1
        scores.append(score)
        print i, score
    elif (str(df['Unnamed: 0'][i])) == '2':
        if (str(df['1a'][i][0])) == 'A':
            score += 1
        if (str(df['2a'][i][0])) == 'A':
            score += 1
        if (str(df['3a'][i][0])) == 'A':
            score += 1
        if (str(df['4a'][i][0])) == 'A':
            score += 1
        if (str(df['5a'][i][0])) == 'A':
            score += 1
        if (str(df['6a'][i][0])) == 'A':
            score += 1
        if (str(df['7a'][i][0])) == 'A':
            score += 1
        if (str(df['8a'][i][0])) == 'A':
            score += 1
        if (str(df['9a'][i][0])) == 'A':
            score += 1
        if (str(df['10a'][i][0])) == 'A':
            score += 1
        if (str(df['11a'][i][0])) == 'A':
            score += 1
        if (str(df['12a'][i][0])) == 'A':
            score += 1
        if (str(df['13a'][i][0])) == 'A':
            score += 1
        if (str(df['14a'][i][0])) == 'A':
            score += 1
        if (str(df['15a'][i][0])) == 'A':
            score += 1
        if (str(df['16a'][i][0])) == 'A':
            score += 1
        if (str(df['17a'][i][0])) == 'A':
            score += 1
        if (str(df['18a'][i][0])) == 'A':
            score += 1
        if (str(df['19a'][i][0])) == 'A':
            score += 1
        if (str(df['20a'][i][0])) == 'A':
            score += 1
        scores.append(score)
        print i, score
    elif (str(df['Unnamed: 0'][i])) == '3':
        if (str(df['1a'][i][0])) == 'A':
            score += 1
        if (str(df['2a'][i][0])) == 'B':
            score += 1
        if (str(df['3a'][i][0])) == 'C':
            score += 1
        if (str(df['4a'][i][0])) == 'A':
            score += 1
        if (str(df['5a'][i][0])) == 'B':
            score += 1
        if (str(df['6a'][i][0])) == 'C':
            score += 1
        if (str(df['7a'][i][0])) == 'A':
            score += 1
        if (str(df['8a'][i][0])) == 'B':
            score += 1
        if (str(df['9a'][i][0])) == 'C':
            score += 1
        if (str(df['10a'][i][0])) == 'A':
            score += 1
        if (str(df['11a'][i][0])) == 'B':
            score += 1
        if (str(df['12a'][i][0])) == 'C':
            score += 1
        if (str(df['13a'][i][0])) == 'A':
            score += 1
        if (str(df['14a'][i][0])) == 'B':
            score += 1
        if (str(df['15a'][i][0])) == 'C':
            score += 1
        if (str(df['16a'][i][0])) == 'A':
            score += 1
        if (str(df['17a'][i][0])) == 'B':
            score += 1
        if (str(df['18a'][i][0])) == 'C':
            score += 1
        if (str(df['19a'][i][0])) == 'A':
            score += 1
        if (str(df['20a'][i][0])) == 'B':
            score += 1
        scores.append(score)
        print i, score
# Out:
# 1 4
# 2 10
# 3 9
# 4 16
# 5 10
# 6 10
# 7 11
# 8 7
# 9 10
# 10 13
# 11 14
# 12 12
# 13 16
# 14 10
# 15 7
# 16 6
# 17 9
# 18 5
# 19 11
# 20 12
# 21 10
# 22 16
# 23 11
# 24 14
# 25 8
# 26 13
# 27 15
# 28 7
# 29 13
# 30 10
# 31 10
# 32 13
# 33 16
# 34 14
# 35 13
# 36 6
# 37 13
# 38 10
# 39 7
# 40 7
# 41 4
# 42 11
# 43 10
# 44 6
# 45 10
# 46 9
# 47 4
# 48 10
# 49 6
# 50 12
# 51 8
# 52 12
# 53 8
# 54 7
# 55 13
# 56 12
# 57 10
# 58 8
# 59 12
# 60 12
# 61 10
# 62 8
# 63 4
# 64 2
# 65 15
# 66 7
# 67 14
# 68 5
# 69 6
# 70 6
# 71 6
# 72 8
# 73 7
# 74 9
# 75 12
# 76 12
# 77 12
# 78 8
# 79 8
# 80 6
# 81 11
# 82 3
# 83 4
# 84 6
# 85 12
# 86 13
# 87 7
# 88 11
# 89 15
# 90 12
# 91 9
# 92 8
# 93 19
# 94 14
# 95 11
# 96 10
# 97 11
# 98 10
# 99 8
# 100 10
# 101 9
# 102 10
# 103 14
# 104 13
# 105 7
# 106 2
# 107 10
# 108 10
# 109 9
# 110 8
# 111 13
# 112 11
# 113 7
# 114 10
# 115 8
# 116 3
# 117 10
# 118 13
# 119 9
# 120 5
# 121 6
# 122 11
# 123 7
# 124 8
# 125 7
# 126 4
# 127 5
# 128 6
# 129 14
# 130 6
# 131 10
# 132 7
# 133 3
# 134 11
# 135 13
# 136 13
# 137 9
# 138 3
# 139 10
# 140 11
# 141 8
# 142 11
# 143 3
# 144 9
# 145 13
# 146 7
# 147 5
# 148 6
# 149 6
# 150 12
# 151 3
# 152 14
# 153 16
# 154 7
# 155 8
# 156 9
# 157 9
# 158 9

# %%
#df['Unnamed: 0']
df['final_score'] = scores

# %%
df.head()
# Out:
#   Unnamed: 0     StartDate        EndDate         Status       IPAddress  \
# 0      Group    Start Date       End Date  Response Type      IP Address
# 1          2  7/11/17 9:46   7/11/17 9:56     IP Address  98.232.116.238
# 2          3  7/11/17 9:41  7/11/17 10:03     IP Address  204.52.135.124
# 3          3  7/10/17 9:29   7/10/17 9:39     IP Address   73.254.83.211
# 4          3  7/11/17 9:35  7/11/17 10:04     IP Address  98.146.231.128
#
#    Progress  Duration (in seconds)  Finished   RecordedDate  \
# 0  Progress  Duration (in seconds)  Finished  Recorded Date
# 1       100                    601      TRUE   7/11/17 9:56
# 2       100                   1332      TRUE  7/11/17 10:03
# 3       100                    569      TRUE   7/10/17 9:39
# 4       100                   1689      TRUE  7/11/17 10:04
#
#           ResponseId     ...                      21a_Browser  \
# 0        Response ID     ...      Browser Meta Info - Browser
# 1  R_2bTLUgDtdE9neLd     ...                           Chrome
# 2  R_12M5kh04xdIFw5e     ...                           Chrome
# 3  R_1NU5yKb58Kn7GvL     ...                           Chrome
# 4  R_2Bx0cD1QFJz4D9n     ...                           Chrome
#
#                    21a_Version                  21a_Operating System  \
# 0  Browser Meta Info - Version  Browser Meta Info - Operating System
# 1                59.0.3071.115                       Windows NT 10.0
# 2                 59.0.3071.86                        Windows NT 6.1
# 3                59.0.3071.115                       Windows NT 10.0
# 4                59.0.3071.115                       Windows NT 10.0
#
#                    21a_Resolution       22a_First Click       22a_Last Click  \
# 0  Browser Meta Info - Resolution  Timing - First Click  Timing - Last Click
# 1                        1120x700                16.207               93.311
# 2                        1536x864                10.499              120.931
# 3                       1920x1080                60.059              209.186
# 4                       1920x1080                 14.74              216.488
#
#         22a_Page Submit       22a_Click Count  mTurkCode final_score
# 0  Timing - Page Submit  Timing - Click Count  mTurkCode           0
# 1                93.643                     6     495836           4
# 2               121.864                     6     489065          10
# 3               209.829                     6     260422           9
# 4               217.087                     6      60785          16
#
# [5 rows x 51 columns]

# %%
df.to_csv('scored241.csv')

# %%
df['Unnamed: 0'].groupby(df['Unnamed: 0']).count()
# Out:
# Unnamed: 0
# 1        54
# 2        53
# 3        51
# Group     1
# Name: Unnamed: 0, dtype: int64

# %%
# Create scoring mechanisms

score1a = []
score1b = []
score1c = []
score2a = []
score2b = []
score2c = []
score3a = []
score3b = []
score3c = []
score4a = []
score4b = []
score4c = []
score5a = []
score5b = []
score5c = []
score6a = []
score6b = []
score6c = []
score7a = []
score7b = []
score7c = []
score8a = []
score8b = []
score8c = []
score9a = []
score9b = []
score9c = []
score10a = []
score10b = []
score10c = []
score11a = []
score11b = []
score11c = []
score12a = []
score12b = []
score12c = []
score13a = []
score13b = []
score13c = []
score14a = []
score14b = []
score14c = []
score15a = []
score15b = []
score15c = []
score16a = []
score16b = []
score16c = []
score17a = []
score17b = []
score17c = []
score18a = []
score18b = []
score18c = []
score19a = []
score19b = []
score19c = []
score20a = []
score20b = []
score20c = []

for i in range(1,len(df)):
    score = 0
    score2 = 0
    score3 = 0
    score4 = 0
    score5 = 0
    score6 = 0
    score7 = 0
    score8 = 0
    score9 = 0
    score10 = 0
    score11 = 0
    score12 = 0
    score13 = 0
    score14 = 0
    score15 = 0
    score16 = 0
    score17 = 0
    score18 = 0
    score19 = 0
    score20 = 0
    if (str(df['Unnamed: 0'][i])) == '1':
        if (str(df['1a'][i][0])) == 'C':
            score += 1
            score1a.append(score)
        if (str(df['2a'][i][0])) == 'B':
            score2 += 1
            score2a.append(score2)
        if (str(df['3a'][i][0])) == 'C':
            score3 += 1
            score3a.append(score3)
        if (str(df['4a'][i][0])) == 'B':
            score4 += 1
            score4a.append(score4)
        if (str(df['5a'][i][0])) == 'C':
            score5 += 1
            score5a.append(score5)
        if (str(df['6a'][i][0])) == 'C':
            score6 += 1
            score6a.append(score6)
        if (str(df['7a'][i][0])) == 'D':
            score7 += 1
            score7a.append(score7)
        if (str(df['8a'][i][0])) == 'A':
            score8 += 1
            score8a.append(score8)
        if (str(df['9a'][i][0])) == 'B':
            score9 += 1
            score9a.append(score9)
        if (str(df['10a'][i][0])) == 'A':
            score10 += 1
            score10a.append(score10)
        if (str(df['11a'][i][0])) == 'D':
            score11 += 1
            score11a.append(score11)
        if (str(df['12a'][i][0])) == 'D':
            score12 += 1
            score12a.append(score12)
        if (str(df['13a'][i][0])) == 'D':
            score13 += 1
            score13a.append(score13)
        if (str(df['14a'][i][0])) == 'D':
            score14 += 1
            score14a.append(score14)
        if (str(df['15a'][i][0])) == 'D':
            score15 += 1
            score15a.append(score15)
        if (str(df['16a'][i][0])) == 'B':
            score16 += 1
            score16a.append(score16)
        if (str(df['17a'][i][0])) == 'A':
            score17 += 1
            score17a.append(score17)
        if (str(df['18a'][i][0])) == 'C':
            score18 += 1
            score18a.append(score18)
        if (str(df['19a'][i][0])) == 'B':
            score19 += 1
            score19a.append(score19)
        if (str(df['20a'][i][0])) == 'A':
            score20 += 1
            score20a.append(score20)
    elif (str(df['Unnamed: 0'][i])) == '2':
        if (str(df['1a'][i][0])) == 'A':
            score += 1
            score1b.append(score)
        if (str(df['2a'][i][0])) == 'A':
            score2 += 1
            score2b.append(score2)
        if (str(df['3a'][i][0])) == 'A':
            score3 += 1
            score3b.append(score3)
        if (str(df['4a'][i][0])) == 'A':
            score4 += 1
            score4b.append(score4)
        if (str(df['5a'][i][0])) == 'A':
            score5 += 1
            score5b.append(score5)
        if (str(df['6a'][i][0])) == 'A':
            score6 += 1
            score6b.append(score6)
        if (str(df['7a'][i][0])) == 'A':
            score7 += 1
            score7b.append(score7)
        if (str(df['8a'][i][0])) == 'A':
            score8 += 1
            score8b.append(score8)
        if (str(df['9a'][i][0])) == 'A':
            score9 += 1
            score9b.append(score9)
        if (str(df['10a'][i][0])) == 'A':
            score10 += 1
            score10b.append(score10)
        if (str(df['11a'][i][0])) == 'A':
            score11 += 1
            score11b.append(score11)
        if (str(df['12a'][i][0])) == 'A':
            score12 += 1
            score12b.append(score12)
        if (str(df['13a'][i][0])) == 'A':
            score13 += 1
            score13b.append(score13)
        if (str(df['14a'][i][0])) == 'A':
            score14 += 1
            score14b.append(score14)
        if (str(df['15a'][i][0])) == 'A':
            score15 += 1
            score15b.append(score15)
        if (str(df['16a'][i][0])) == 'A':
            score16 += 1
            score16b.append(score16)
        if (str(df['17a'][i][0])) == 'A':
            score17 += 1
            score17b.append(score17)
        if (str(df['18a'][i][0])) == 'A':
            score18 += 1
            score18b.append(score18)
        if (str(df['19a'][i][0])) == 'A':
            score19 += 1
            score19b.append(score19)
        if (str(df['20a'][i][0])) == 'A':
            score20 += 1
            score20b.append(score20)
    elif (str(df['Unnamed: 0'][i])) == '3':
        if (str(df['1a'][i][0])) == 'A':
            score += 1
            score1c.append(score)
        if (str(df['2a'][i][0])) == 'B':
            score2 += 1
            score2c.append(score2)
        if (str(df['3a'][i][0])) == 'C':
            score3 += 1
            score3c.append(score3)
        if (str(df['4a'][i][0])) == 'A':
            score4 += 1
            score4c.append(score4)
        if (str(df['5a'][i][0])) == 'B':
            score5 += 1
            score5c.append(score5)
        if (str(df['6a'][i][0])) == 'C':
            score6 += 1
            score6c.append(score6)
        if (str(df['7a'][i][0])) == 'A':
            score7 += 1
            score7c.append(score7)
        if (str(df['8a'][i][0])) == 'B':
            score8 += 1
            score8c.append(score8)
        if (str(df['9a'][i][0])) == 'C':
            score9 += 1
            score9c.append(score9)
        if (str(df['10a'][i][0])) == 'A':
            score10 += 1
            score10b.append(score10)
        if (str(df['11a'][i][0])) == 'B':
            score11 += 1
            score11c.append(score11)
        if (str(df['12a'][i][0])) == 'C':
            score12 += 1
            score12c.append(score12)
        if (str(df['13a'][i][0])) == 'A':
            score13 += 1
            score13c.append(score13)
        if (str(df['14a'][i][0])) == 'B':
            score14 += 1
            score14c.append(score14)
        if (str(df['15a'][i][0])) == 'C':
            score15 += 1
            score15c.append(score15)
        if (str(df['16a'][i][0])) == 'A':
            score16 += 1
            score16c.append(score16)
        if (str(df['17a'][i][0])) == 'B':
            score17 += 1
            score17c.append(score17)
        if (str(df['18a'][i][0])) == 'C':
            score18 += 1
            score18c.append(score18)
        if (str(df['19a'][i][0])) == 'A':
            score19 += 1
            score19c.append(score19)
        if (str(df['20a'][i][0])) == 'B':
            score20 += 1
            score20c.append(score20)

print(sum(score20a))
print(sum(score20b))
print(sum(score20c))
# Out:
# 44
# 39
# 46
